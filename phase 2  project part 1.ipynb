# %%
import pandas as pd
netflixl=pd.read_csv("C:\\Users\\Y.V.Keerthana Rani\\Downloads\\dataset - netflix1.csv")

# %%
#viewing the netflixl data set and we are finding how many components are there in netflixl type data and counting them..

# %%
netflixl["type"].value_counts()
# Out:
# Movie      6126
# TV Show    2664
# Name: type, dtype: int64

# %%
# importing both matplotlib and seaborn for netflixl data set and we are doing  bar graphy for all parametersin netflixl data set.
#There are not catagorical values...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
netflixl["type"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
netflixl["director"].value_counts()
# Out:
# Not Given                         2588
# Rajiv Chilaka                       20
# Alastair Fothergill                 18
# Raúl Campos, Jan Suter              18
# Suhas Kadav                         16
#                                   ...
# Matt D'Avella                        1
# Parthiban                            1
# Scott McAboy                         1
# Raymie Muzquiz, Stu Livingston       1
# Mozez Singh                          1
# Name: director, Length: 4528, dtype: int64

# %%
# this gives the director directed movies which are present in netflixl data set.#from the above we can say that the mode for the director column of netflixl data set is not given.In our netflixl data for 2588 movies/TV Shows the director name is not given without considering it  Rajiv Chilaka director has higher number of movies/TV Shows than others.

# %%
netflixl["country"].value_counts()
# Out:
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
#                   ...
# Iran                 1
# West Germany         1
# Greece               1
# Zimbabwe             1
# Soviet Union         1
# Name: country, Length: 86, dtype: int64

# %%
# this gives the list of countries that was been directed movies or tv shows...

# %%
netflixl["country"].value_counts().plot(kind="bar",figsize=(15,8))
# Out:
# <Axes: >

# %%
# we will be taking top 10 countries for best view of graph...

# %%
a=netflixl["country"].value_counts()

# %%
a[:10].plot(kind='bar',figsize=(15,8))
plt.xlabel("country")
plt.ylabel("frequency")
plt.title("country wise movies/tv shows")
# Out:
# Text(0.5, 1.0, 'country wise movies/tv shows')

# %%
# here we are sorting the date_added where we can

# %%
import pandas as pd
netflixl=pd.read_csv("C:\\Users\\Y.V.Keerthana Rani\\Downloads\\dataset - netflix1.csv")
netflixl["date_added"]=pd.to_datetime(netflixl["date_added"])

# %%
netflixl
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# ...

# %%
netflixl1=netflixl.sort_values(by="date_added")

# %%
netflixl1
# Out:
#      show_id     type                                title  \
# 4253   s5958    Movie                 To and From New York
# 8423   s6612  TV Show                      Dinner for Five
# 4252   s5957    Movie              Just Another Love Story
# 4251   s5956    Movie                             Splatter
# 5381   s7371    Movie          Mad Ron's Prevues from Hell
# ...      ...      ...                                  ...
# 23        s7    Movie     My Little Pony: A New Generation
# 6572      s5  TV Show                         Kota Factory
# 6586     s11  TV Show  Vendetta: Truth, Lies and The Mafia
# 6        s10    Movie                         The Starling
# 0         s1    Movie                 Dick Johnson Is Dead
#
#                            director        country date_added  release_year  \
# 4253           Sorin Dan Mihalcescu  United States 2008-01-01          2006
# 8423                      Not Given  United States 2008-02-04          2007
# ...

# %%
m=netflixl1.groupby("date_added").count()

# %%
# these are grouped by netflixl data set of all parameters

# %%
m
# Out:
#             show_id  type  title  director  country  release_year  rating  \
# date_added
# 2008-01-01        1     1      1         1        1             1       1
# 2008-02-04        1     1      1         1        1             1       1
# 2009-05-05        1     1      1         1        1             1       1
# 2009-11-18        1     1      1         1        1             1       1
# 2010-11-01        1     1      1         1        1             1       1
# ...             ...   ...    ...       ...      ...           ...     ...
# 2021-09-21        5     5      5         5        5             5       5
# 2021-09-22        9     9      9         9        9             9       9
# 2021-09-23        2     2      2         2        2             2       2
# 2021-09-24       10    10     10        10       10            10      10
# 2021-09-25        1     1      1         1        1             1       1
#
#             duration  listed_in
# date_added
# ...

# %%
# import the matplotlib and seaborn to plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,8))
plt.plot(m.index,m["show_id"])
plt.xlabel("date_added")
plt.ylabel("number of movies/tv shows")
# Out:
# Text(0, 0.5, 'number of movies/tv shows')

# %%
# after 2016 the movies/tv shows are been increased  may be increase in technology ...

# %%
# we are drawing the graph about release_year....

# %%
netflixl["release_year"].value_counts().plot(kind="bar",figsize=(15,8))
# Out:
# <Axes: >

# %%
# we are considering only top 10

# %%
a=netflixl["release_year"].value_counts()

# %%
a[:10].plot(kind="bar")
plt.xlabel("release_date")
plt.ylabel(" release_numbers")
# Out:
# Text(0, 0.5, ' release_numbers')

# %%
# the top 10 years with respective movies/tv shows are added into netflixl are 2018,2017,2019,2020,2016,2015,2014,2013 and 2012....

# %%
# graph for rating data....

# %%
netflixl["rating"].value_counts().plot(kind="bar",figsize=(15,8))
# Out:
# <Axes: >

# %%
# the  most of tvshows/movies are rated by tv-ma above 3000 followed by tv-14 upto 2000 and so on..... 
#among the 8790 movies /tv shows 3000 are rated by tv-ma

# %%
netflixl["duration"].value_counts().plot(kind="bar",figsize=(15,8))
# Out:
# <Axes: >

# %%
c=netflixl["duration"].value_counts()
c[:10].plot(kind="bar")
plt.xlabel("duration_film/tv shows")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
#the most of tv shows are present in the netflixl are having a duration of one season upto 1750 frequency.
# most of the movies are presented in the netflixl are having duration around 90 mins...

# %%
b=netflixl["listed_in"].value_counts()
b[:10].plot(kind="bar")
plt.xlabel("listed_film/tv shows")
plt.ylabel("listed_number")
# Out:
# Text(0, 0.5, 'listed_number')

# %%
# most of the movies are been selected in netflixl based on dramas,international movies and documentries,. 
#coming to the tv shows stand-up comdey is motly available in netflixl.
